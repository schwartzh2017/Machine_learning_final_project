# %%
# Christy's work:

import numpy as np
import pandas as pd

df = pd.read_csv("speeddating.csv", low_memory=False)
df = df.applymap(lambda x: np.nan if x == '?' else x)


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

print(df.isnull().any())

print(df.loc[2])

#--------------------------

# Haleigh's edits/cleaning:

# remove NAs
df2 = df.dropna()
df2.shape #only have 1048 rows left - should we use this one?
df.shape #compared to 8378 rows when there are NAs
df2.dtypes #objects and integers (binned integers are objects)

#will continue with df2 but can just copy/paste with df if we decide to use that one instead

#I think it's okay to keep some of the numeric data binned since that might help to find patterns between variables later, but I can be convinced otherwise. What do you all think?

#remove single quotes from race, race_o cols, and field cols
cols_to_check = ['race', 'race_o', 'field']
df2[cols_to_check] = df2[cols_to_check].replace({'\'':''}, regex=True)
df2['race'] #check
df2['race_o'] #check
df2['field'] #check

#lowercase everything (including field since they weren't all upper or lowercase in field)
df2['field'] = df2['field'].apply(lambda x: x.lower()) #I couldn't get this to work using cols_to_check for some reason. also tried str.lower but it didn't work, so did it individually instead since only three cols
df2['race'] = df2['race'].apply(lambda x: x.lower())
df2['race_o'] = df2['race_o'].apply(lambda x: x.lower())
df2['race'] #check
df2['race_o'] #check
df2['field'] #check

#check that all ? were removed/detected as NA -- if use df instead, make sure to convert all ? to NA 
"?" in df2 #false, so they were removed 

# export to csv
df2.to_csv('clean_speeddating.csv')

#--------------------------

#repeat for df

#remove single quotes from race, race_o cols, and field cols
cols_to_check = ['race', 'race_o', 'field']
df[cols_to_check] = df[cols_to_check].replace({'\'':''}, regex=True)
#df['race'] #check
#df['race_o'] #check
#df['field'] #check

#lowercase everything (including field since they weren't all upper or lowercase in field)
df['field'] = df['field'].astype(str)
df['field'] = df['field'].apply(lambda x: str(x.lower()))

df['race'] = df['race'].astype(str)
df['race'] = df['race'].apply(lambda x: str(x.lower()))

df['race_o'] = df['race_o'].astype(str)
df['race_o'] = df['race_o'].apply(lambda x: str(x.lower()))

#df['race'] #check
#df['race_o'] #check
#df['field'] #check

# #check that all ? were removed/detected as NA -- if use df instead, make sure to convert all ? to NA 
"?" in df #false, so they were removed 

# export to csv
df.to_csv('clean_speeddating_with_na.csv')
# Out:
# has_null                           False
# wave                               False
# gender                             False
# age                                 True
# age_o                               True
# d_age                              False
# d_d_age                            False
# race                                True
# race_o                              True
# samerace                           False
# importance_same_race                True
# importance_same_religion            True
# d_importance_same_race             False
# d_importance_same_religion         False
# field                               True
# pref_o_attractive                   True
# pref_o_sincere                      True
# pref_o_intelligence                 True
# pref_o_funny                        True
# pref_o_ambitious                    True
# pref_o_shared_interests             True
# d_pref_o_attractive                False
# d_pref_o_sincere                   False
# d_pref_o_intelligence              False
# d_pref_o_funny                     False
# d_pref_o_ambitious                 False
# d_pref_o_shared_interests          False
# attractive_o                        True
# sinsere_o                           True
# intelligence_o                      True
# funny_o                             True
# ambitous_o                          True
# shared_interests_o                  True
# d_attractive_o                     False
# d_sinsere_o                        False
# d_intelligence_o                   False
# d_funny_o                          False
# d_ambitous_o                       False
# d_shared_interests_o               False
# attractive_important                True
# sincere_important                   True
# intellicence_important              True
# funny_important                     True
# ambtition_important                 True
# shared_interests_important          True
# d_attractive_important             False
# d_sincere_important                False
# d_intellicence_important           False
# d_funny_important                  False
# d_ambtition_important              False
# d_shared_interests_important       False
# attractive                          True
# sincere                             True
# intelligence                        True
# funny                               True
# ambition                            True
# d_attractive                       False
# d_sincere                          False
# d_intelligence                     False
# d_funny                            False
# d_ambition                         False
# attractive_partner                  True
# sincere_partner                     True
# intelligence_partner                True
# funny_partner                       True
# ambition_partner                    True
# shared_interests_partner            True
# d_attractive_partner               False
# d_sincere_partner                  False
# d_intelligence_partner             False
# d_funny_partner                    False
# d_ambition_partner                 False
# d_shared_interests_partner         False
# sports                              True
# tvsports                            True
# exercise                            True
# dining                              True
# museums                             True
# art                                 True
# hiking                              True
# gaming                              True
# clubbing                            True
# reading                             True
# tv                                  True
# theater                             True
# movies                              True
# concerts                            True
# music                               True
# shopping                            True
# yoga                                True
# d_sports                           False
# d_tvsports                         False
# d_exercise                         False
# d_dining                           False
# d_museums                          False
# d_art                              False
# d_hiking                           False
# d_gaming                           False
# d_clubbing                         False
# d_reading                          False
# d_tv                               False
# d_theater                          False
# d_movies                           False
# d_concerts                         False
# d_music                            False
# d_shopping                         False
# d_yoga                             False
# interests_correlate                 True
# d_interests_correlate              False
# expected_happy_with_sd_people       True
# expected_num_interested_in_me       True
# expected_num_matches                True
# d_expected_happy_with_sd_people    False
# d_expected_num_interested_in_me    False
# d_expected_num_matches             False
# like                                True
# guess_prob_liked                    True
# d_like                             False
# d_guess_prob_liked                 False
# met                                 True
# decision                           False
# decision_o                         False
# match                              False
# dtype: bool
# has_null                                                                 1
# wave                                                                     1
# gender                                                              female
# age                                                                     21
# age_o                                                                   22
# d_age                                                                    1
# d_d_age                                                              [0-1]
# race                               'Asian/Pacific Islander/Asian-American'
# race_o                             'Asian/Pacific Islander/Asian-American'
# samerace                                                                 1
# importance_same_race                                                     2
# importance_same_religion                                                 4
# d_importance_same_race                                               [2-5]
# d_importance_same_religion                                           [2-5]
# field                                                                  Law
# pref_o_attractive                                                       19
# pref_o_sincere                                                          18
# pref_o_intelligence                                                     19
# pref_o_funny                                                            18
# pref_o_ambitious                                                        14
# pref_o_shared_interests                                                 12
# d_pref_o_attractive                                                [16-20]
# d_pref_o_sincere                                                   [16-20]
# d_pref_o_intelligence                                              [16-20]
# d_pref_o_funny                                                     [16-20]
# d_pref_o_ambitious                                                  [0-15]
# d_pref_o_shared_interests                                           [0-15]
# attractive_o                                                            10
# sinsere_o                                                               10
# intelligence_o                                                          10
# funny_o                                                                 10
# ambitous_o                                                              10
# shared_interests_o                                                      10
# d_attractive_o                                                      [9-10]
# d_sinsere_o                                                         [9-10]
# d_intelligence_o                                                    [9-10]
# d_funny_o                                                           [9-10]
# d_ambitous_o                                                        [9-10]
# d_shared_interests_o                                                [9-10]
# attractive_important                                                    15
# sincere_important                                                       20
# intellicence_important                                                  20
# funny_important                                                         15
# ambtition_important                                                     15
# shared_interests_important                                              15
# d_attractive_important                                              [0-15]
# d_sincere_important                                                [16-20]
# d_intellicence_important                                           [16-20]
# d_funny_important                                                   [0-15]
# d_ambtition_important                                               [0-15]
# d_shared_interests_important                                        [0-15]
# attractive                                                               6
# sincere                                                                  8
# intelligence                                                             8
# funny                                                                    8
# ambition                                                                 7
# d_attractive                                                         [6-8]
# d_sincere                                                            [6-8]
# d_intelligence                                                       [6-8]
# d_funny                                                              [6-8]
# d_ambition                                                           [6-8]
# attractive_partner                                                       5
# sincere_partner                                                          8
# intelligence_partner                                                     9
# funny_partner                                                            8
# ambition_partner                                                         5
# shared_interests_partner                                                 7
# d_attractive_partner                                                 [0-5]
# d_sincere_partner                                                    [6-8]
# d_intelligence_partner                                              [9-10]
# d_funny_partner                                                      [6-8]
# d_ambition_partner                                                   [0-5]
# d_shared_interests_partner                                           [6-8]
# sports                                                                   9
# tvsports                                                                 2
# exercise                                                                 8
# dining                                                                   9
# museums                                                                  1
# art                                                                      1
# hiking                                                                   5
# gaming                                                                   1
# clubbing                                                                 5
# reading                                                                  6
# tv                                                                       9
# theater                                                                  1
# movies                                                                  10
# concerts                                                                10
# music                                                                    9
# shopping                                                                 8
# yoga                                                                     1
# d_sports                                                            [9-10]
# d_tvsports                                                           [0-5]
# d_exercise                                                           [6-8]
# d_dining                                                            [9-10]
# d_museums                                                            [0-5]
# d_art                                                                [0-5]
# d_hiking                                                             [0-5]
# d_gaming                                                             [0-5]
# d_clubbing                                                           [0-5]
# d_reading                                                            [6-8]
# d_tv                                                                [9-10]
# d_theater                                                            [0-5]
# d_movies                                                            [9-10]
# d_concerts                                                          [9-10]
# d_music                                                             [9-10]
# d_shopping                                                           [6-8]
# d_yoga                                                               [0-5]
# interests_correlate                                                   0.16
# d_interests_correlate                                             [0-0.33]
# expected_happy_with_sd_people                                            3
# expected_num_interested_in_me                                            2
# expected_num_matches                                                     4
# d_expected_happy_with_sd_people                                      [0-4]
# d_expected_num_interested_in_me                                      [0-3]
# d_expected_num_matches                                               [3-5]
# like                                                                     7
# guess_prob_liked                                                       NaN
# d_like                                                               [6-8]
# d_guess_prob_liked                                                   [0-4]
# met                                                                      1
# decision                                                                 1
# decision_o                                                               1
# match                                                                    1
# Name: 2, dtype: object
# /var/folders/s3/xv1zbv396w155jxwc4kwhqlh0000gn/T/ipykernel_20198/2368353898.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[cols_to_check] = df2[cols_to_check].replace({'\'':''}, regex=True)
# /var/folders/s3/xv1zbv396w155jxwc4kwhqlh0000gn/T/ipykernel_20198/2368353898.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['field'] = df2['field'].apply(lambda x: x.lower()) #I couldn't get this to work using cols_to_check for some reason. also tried str.lower but it didn't work, so did it individually instead since only three cols
# /var/folders/s3/xv1zbv396w155jxwc4kwhqlh0000gn/T/ipykernel_20198/2368353898.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['race'] = df2['race'].apply(lambda x: x.lower())
# /var/folders/s3/xv1zbv396w155jxwc4kwhqlh0000gn/T/ipykernel_20198/2368353898.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['race_o'] = df2['race_o'].apply(lambda x: x.lower())

# %%
cols_to_check = ['race', 'race_o', 'field']
df[cols_to_check] = df[cols_to_check].replace({'\'':''}, regex=True)
#df['race'] #check
#df['race_o'] #check
#df['field'] #check

#lowercase everything (including field since they weren't all upper or lowercase in field)
df['field'] = df['field'].astype(str)
df['field'] = df['field'].apply(lambda x: str(x.lower()))

df['race'] = df['race'].astype(str)
df['race'] = df['race'].apply(lambda x: str(x.lower()))

df['race_o'] = df['race_o'].astype(str)
df['race_o'] = df['race_o'].apply(lambda x: str(x.lower()))

#df['race'] #check
#df['race_o'] #check
#df['field'] #check

# #check that all ? were removed/detected as NA -- if use df instead, make sure to convert all ? to NA 
"?" in df #false, so they were removed
# Out:
# False
